# %% [markdown]
# # Bus Booking Analytics - Data Generation
#
# This notebook demonstrates the synthetic data generation strategy.
# To build a realistic relational model and demonstrate our ETL pipelines, we generate a raw dataset of **2,000 base booking records** and purposely inject key anomalies ("dirt") like duplicate records, missing fares, negative values, and inconsistent formatting.
#
# The entities generated are:
# 1. **Customers**: 301 records mapped to `Customer_ID` values 100 to 400 (contains casing dirt and missing phone numbers).
# 2. **Buses**: 11 records mapped to `Bus_ID` values 200 to 210.
# 3. **Routes**: 11 records mapped to `Route_ID` values 300 to 310 (contains mixed-case source/destination dirt).
# 4. **Bookings (Raw)**: 2,100 records containing injected duplicates, invalid dates, out-of-capacity seats, and formatting discrepancies.

# %% [markdown]
# ### Step 1: Imports & Setup

# %%
import pandas as pd
import os
import sys

# Import data_generator from current directory
import data_generator

print("Libraries and modules loaded successfully!")
# Out:
# Libraries and modules loaded successfully!

# %% [markdown]
# ### Step 2: Generate the Raw Dirty Datasets
# We invoke the generation script to create the datasets.

# %%
# Execute generation
data_generator.main()
# Out:
# Generating base entities...
# Generating raw bookings with injected dirt (>1000 rows)...
# Generated Raw Bookings: 2100 rows. Saved to data/bus_booking_raw.csv
# Generated Customers: 301 rows. Saved to data/customers.csv
# Generated Buses: 11 rows. Saved to data/buses.csv
# Generated Routes: 11 rows. Saved to data/routes.csv

# %% [markdown]
# ### Step 3: Inspect Raw Datasets & Injected Dirt

# %% [markdown]
# #### 1. Bookings Raw Dataset (contains formatting dirt and duplicates)

# %%
bookings_raw = pd.read_csv('../data/bus_booking_raw.csv')
print(f"Raw Bookings Shape: {bookings_raw.shape} (Expected: 2100 rows due to duplicates)")
print(f"Duplicates present: {bookings_raw.duplicated(subset=['Booking_ID']).sum()}")
print(f"Null Fare amounts present: {bookings_raw['Fare_Amount'].isnull().sum()}")
print(f"Negative Fare amounts present: {(bookings_raw['Fare_Amount'] < 0).sum()}")
bookings_raw.head(10)
# Out:
# Raw Bookings Shape: (2100, 9) (Expected: 2100 rows due to duplicates)
# Duplicates present: 100
# Null Fare amounts present: 41
# Negative Fare amounts present: 31
#    Booking_ID  Customer_ID  Bus_ID  Route_ID Booking_Date Travel_Date  \
# 0        1035          340     202       310   2025-02-24  2025-02-27
# 1        1177          223     202       308   06-29-2025  07-04-2025
# 2          68          182     201       303   2025-05-11  2025-05-15
# 3        1331          141     201       306   2025-06-29  2025-06-30
# 4         651          377     209       300   2025-05-26  2025-05-23
# 5        1869          272     201       307   2025-03-29  2025-04-03
# 6         987          311     209       310   2025-03-27  2025-03-29
# 7         553          284     206       304   2025-03-09  2025-03-14
# 8        1428          240     202       304   2025-05-09  2025-05-10
# 9        1669          118     207       307   2025-01-28  2025-01-29
#
#    Seat_Number  Fare_Amount Booking_Status
# 0           37        545.0      Confirmed
# 1           13       1070.0        pEnDiNg
# 2           22       1055.0      Cancelled
# 3           25        575.0      Confirmed
# 4           13        275.0        Pending
# 5           34        875.0      Cancelled
# 6           42        395.0      Confirmed
# 7           17       1145.0      Cancelled
# 8           39       1145.0        Pending
# 9           15        725.0      Confirmed

# %% [markdown]
# #### 2. Customers Dataset (contains casing and null phone number dirt)

# %%
customers = pd.read_csv('../data/customers.csv')
print(f"Customers Shape: {customers.shape}")
print(f"Missing phone numbers: {customers['Phone'].isnull().sum()}")
customers.head(10)
# Out:
# Customers Shape: (301, 6)
# Missing phone numbers: 21
#    Customer_ID              Name                       Email         Phone  \
# 0          100      suresh gupta      suresh.gupta@email.com           NaN
# 1          101    ARJUN KULKARNI    arjun.kulkarni@email.com  8.481368e+09
# 2          102       sAnDeEp rAo       sandeep.rao@email.com  9.623709e+09
# 3          103    Deepika Pandey    deepika.pandey@email.com  8.117575e+09
# 4          104       Meera Gupta       meera.gupta@email.com  7.811654e+09
# 5          105         sai yadav         sai.yadav@email.com  9.773211e+09
# 6          106      ARJUN PANDEY      arjun.pandey@email.com  8.851320e+09
# 7          107         sAi pAtIl         sai.patil@email.com  8.225079e+09
# 8          108        Ishaan Rao        ishaan.rao@email.com  9.842572e+09
# 9          109  Simran Choudhury  simran.choudhury@email.com  7.200551e+09
#
#    Gender    Age
# 0    male    NaN
# 1    MALE   -8.0
# 2       F  141.0
# 3    Male   50.0
# 4    Male   61.0
# 5    Male   50.0
# 6  Female   19.0
# 7  Female   53.0
# 8  Female   75.0
# 9    Male   73.0

# %% [markdown]
# #### 3. Routes Dataset (contains casing dirt)

# %%
routes = pd.read_csv('../data/routes.csv')
routes.head(11)
# Out:
#     Route_ID     Source Destination  Distance  Source_Latitude  \
# 0        300     mUmBaI        PuNe       150          19.0760
# 1        301  Bangalore     Chennai       350          12.9716
# 2        302      Delhi      Jaipur       270          28.6139
# 3        303  hYdErAbAd   BaNgAlOrE       570          17.3850
# 4        304    Chennai   Hyderabad       630          13.0827
# 5        305     Mumbai   Ahmedabad       520          19.0760
# 6        306      dElHi  ChAnDiGaRh       250          28.6139
# 7        307       Pune         Goa       450          18.5204
# 8        308    Kolkata       Patna       580          22.5726
# 9        309  bAnGaLoRe   HyDeRaBaD       570          12.9716
# 10       310      Delhi        Agra       230          28.6139
#
#     Source_Longitude  Dest_Latitude  Dest_Longitude
# 0            72.8777        18.5204         73.8567
# 1            77.5946        13.0827         80.2707
# 2            77.2090        26.9124         75.7873
# 3            78.4867        12.9716         77.5946
# 4            80.2707        17.3850         78.4867
# 5            72.8777        23.0225         72.5714
# 6            77.2090        30.7333         76.7794
# 7            73.8567        15.2993         74.1240
# 8            88.3639        25.5941         85.1376
# 9            77.5946        17.3850         78.4867
# 10           77.2090        27.1767         78.0081
